# %% [markdown]
# <a href="https://colab.research.google.com/github/JAEILJEON/JAEIL_ML_LAB/blob/main/ml_lec_dnn_%ED%80%B4%EC%A6%88_%26_code_%EA%B3%B5%EB%B6%80_210706.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1에폭 / size 100 / 10 iteration
# 여기서는 그럼 iteration이 배치 수인가 보네.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
